# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicoli-Silva/Dados-Queimadas/blob/main/Exerc%C3%ADcio_de_Banco_de_Dados_temaQueimadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![pretalab.png](data:image/png;base64,...)

# %% [markdown]
# #Bem Vinde ao Exercício de Banco de Dados do Tema - 1
#
# 1. **O link para o Banco de Dados de Queimadas é:** [Dados](https://basedosdados.org/dataset/f06f3cdc-b539-409b-b311-1ff8878fb8d9?table=a3696dc2-4dd1-4f7e-9769-6aa16a1556b8).

# %% [markdown]
# # **Tema Banco de dados de Queimadas**

# %% [markdown]
# ## Pergunta 1: Qual estado teve o maior número de focos de queimadas em 2022?

# %% [markdown]
# O estado com maior número de focos foi **Paraiba**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 2: Qual o ano com mais queimadas nos últimos 5 anos no Brasil?

# %% [markdown]
# O ano com maior numero de queimadas foi **2020**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 3: Qual foi o bioma mais afetado pelas queimadas em 2021?

# %% [markdown]
# O Bioma mais afetado foi o da **Amazonia**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 4: Quantos Estados e anos tem? (Coloque de forma que Estados e Anos não se repita)

# %% [markdown]
# Querida prof esse eu não consegui 😰

# %% [markdown]
# ## Pergunta 5: Qual foi a média de focos de queimadas por estado no Brasil em 2020?

# %% [markdown]
# **RO**
# 11145.0
#
# **AC**
# 9193.0
#
# **AM**
# 16729.0
#
# **RR**
# 1930.0
#
# **PA**
# 38603.0
#
# **AP**
# 750.0
#
# **TO**
# 12093.0
#
# **MA**
# 16817.0
#
# **PI**
# 9317.0
#
# **CE**
# 3979.0
#
# **RN**
# 664.0
#
# **PB**
# 910.0
#
# **PE**
# 1017.0
#
# **AL**
# 159.0
#
# **SE**
# 77.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 6: Qual município teve mais focos de queimadas em 2021 no estado do Mata Atlântica?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 7: Qual a evolução anual do número de queimadas no Cerrado entre 2015 e 2022?

# %% [markdown]
# **2015**
# 75094
#
# **2016**
# 58833
#
# **2017**
# 66762
#
# **2018**
# 39449
#
# **2019**
# 63874
#
# **2020**
# 63819
#
# **2021**
# 62728
#
# **2022**
# 56885

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pergunta 8: Quantos focos de queimadas foram registrados por bioma no ano de 2005 no banco de dados do INPE?

# %% [markdown]
# **Amazônia**
# 213720
#
# **Cerrado**
# 85747
#
# **Caatinga**
# 26149
#
# **Mata Atlântica**
# 23273
#
# **Pantanal**
# 12536
#
# **Pampa**
# 1138

# %% [markdown]
# ![image.png](data:image/png;base64,...)
